# %%
# %pip install gdown
# Out:
# Requirement already satisfied: gdown in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
import zipfile
import os

# Enlace de la carpeta comprimida en Google Drive (debe estar configurado como público o compartir el enlace)
url = 'https://drive.google.com/uc?id=1w2D-lwIvD53bDOqD6WlX81Ma2qERoOws'
output = 'Models.zip'

# Descargar la carpeta comprimida
gdown.download(url, output, quiet=False)

# Ruta del archivo zip que deseas descomprimir
archivo_zip = 'Models.zip'
# Ruta donde quieres extraer los archivos
destino = 'ModelLanguage/'

# Si el directorio de destino no existe, lo creamos
if not os.path.exists(destino):
    os.makedirs(destino)

# Descomprimir el archivo zip
with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
    zip_ref.extractall(destino)

print(f"Archivo descomprimido en {destino}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1w2D-lwIvD53bDOqD6WlX81Ma2qERoOws
# From (redirected): https://drive.google.com/uc?id=1w2D-lwIvD53bDOqD6WlX81Ma2qERoOws&confirm=t&uuid=78f86a16-ab69-4363-88e8-763d1c24a939
# To: /home/andoni/Documentos/pruebas/TranslatorBasicTransformer/Models.zip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 2.43G/2.43G [09:13<00:00, 4.39MB/s]
# Archivo descomprimido en ModelLanguage/

# %%
import gdown
import tarfile
import os

# Enlace de uno de los archivos tar.gz en Google Drive (debe estar configurado como público o compartir el enlace)
url = 'https://drive.google.com/uc?id=1JfyRu0uyMk7KxPyvoCUUqvaK9VXJSE0M'
output = 'translatorEN-ES.tar.gz'

# Descargar el archivo tar.gz
gdown.download(url, output, quiet=False)

# Ruta del archivo .tar.gz que deseas descomprimir
archivo_tar_gz = 'translatorEN-ES.tar.gz'
# Ruta donde quieres extraer los archivos
destino = 'ModelLanguage/'

# Si el directorio de destino no existe, lo creamos
if not os.path.exists(destino):
    os.makedirs(destino)

# Descomprimir el archivo tar.gz
with tarfile.open(archivo_tar_gz, 'r:gz') as tar:
    tar.extractall(path=destino)

print(f"Archivo descomprimido en {destino}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JfyRu0uyMk7KxPyvoCUUqvaK9VXJSE0M
# From (redirected): https://drive.google.com/uc?id=1JfyRu0uyMk7KxPyvoCUUqvaK9VXJSE0M&confirm=t&uuid=9db33792-2bb3-4d22-b01e-56c94e5a8692
# To: /home/andoni/Documentos/pruebas/TranslatorBasicTransformer/translatorEN-ES.tar.gz
# 100%|██████████| 335M/335M [00:38<00:00, 8.66MB/s]
# Archivo descomprimido en ModelLanguage/

# %%
import gdown

# Enlace de la carpeta comprimida en Google Drive (debe estar configurado como público o compartir el enlace)
url = 'https://drive.google.com/uc?id=1uEUCSEZ4FhvkLZ3U2ZxXfTtemSNseRCd'
output = 'Models/modelo_naive_bayes.pkl'

# Descargar la carpeta comprimida
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uEUCSEZ4FhvkLZ3U2ZxXfTtemSNseRCd
# To: /home/andoni/Documentos/pruebas/TranslatorBasicTransformer/Models/modelo_naive_bayes.pkl
# 100%|██████████| 8.20M/8.20M [00:00<00:00, 11.7MB/s]
# 'Models/modelo_naive_bayes.pkl'

# %% [markdown]
# Código con BLEU

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %%
def calculate_bleu(reference, candidate):
    smoothing_function = SmoothingFunction().method1  # Suavizado para frases cortas
    return sentence_bleu([reference], candidate, smoothing_function=smoothing_function)

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/andoni/Documentos/pruebas/.venv/lib/python3.10/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def calculate_bleu(reference, candidate):
    smoothie = SmoothingFunction().method4  
    return sentence_bleu([reference], candidate, smoothing_function=smoothie)

# %%
import tensorflow as tf
import joblib
from langdetect import detect
import tensorflow_text

# Diccionario de mapeo de etiquetas numéricas a idiomas
etiquetas_a_idiomas = {
    0: 'spa', 1: 'eng', 2: 'deu', 3: 'por', 4: 'fra', 5: 'ita'
}


# Cargar los modelos de traducción
def load_translation_models():
    models = {
        "EN": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/translatorES-ENhalf'),
        "FR": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorES-FR'),
        "DE": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorES-DEhalf'),
        "IT": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorES-IT'),
        "PT": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorES-PT'),
        "ENR": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/translatorEN-ES'),
        "FRR": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorFR-ES'),
        "DER": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorDE-ES'),
        "ITR": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorIT-ES'),
        "PTR": tf.saved_model.load('/home/andoni/Documentos/pruebas/TranslatorBasicTransformer/ModelLanguage/Models/translatorPT-ES'),
    }
    return models

# Cargar el modelo de detección de idioma
def load_language_detection_model():
    return joblib.load('Models/modelo_naive_bayes.pkl')

# Función para detectar el idioma usando el modelo o langdetect
def detect_language(text, model):
    try:
        # Intentamos usar el modelo cargado para predecir el idioma
        predicted_language_idx = model.predict([text])[0]
        print(f"Predicción del modelo (índice): {predicted_language_idx}")
        
        # Mapeamos el índice a la etiqueta de idioma
        predicted_language = etiquetas_a_idiomas.get(predicted_language_idx, 'otros')
        
        # Si el idioma es uno de los soportados, lo devolvemos
        supported_languages = ['spa', 'eng', 'deu', 'por', 'fra', 'ita']
        if predicted_language in supported_languages:
            return predicted_language
        else:
            return 'otros'  # Devolver "otros" si el idioma no está en los soportados
    except:
        # Si el modelo no puede identificar el idioma, usamos langdetect
        detected_language = detect(text)
        return detected_language

# Función para traducir a español si el idioma detectado es uno de los soportados
def translate_to_spanish(text, model):
    return model(text).numpy().decode('utf-8')

# Función para traducir desde español a otro idioma
def translate_from_spanish(text, target_lang, models):
    if target_lang in models:
        model = models[target_lang]
        return model(text).numpy().decode('utf-8')
    else:
        return f"Lo siento, no hay opción para traducir a {target_lang}."

def main():
    
    try:
        # Cargar modelos de traducción y detección
        models = load_translation_models()
        print('Modelos de traducción cargados.')
        
        language_model = load_language_detection_model()
        print('Modelo de detección de idioma cargado.')
        
        # Solicitar entrada al usuario
        text = input("Introduce una frase para traducir: ")
        detected_language = detect_language(text, language_model)
        print(f"Idioma detectado: {detected_language}")
        
        if detected_language == 'spa':
            # Elegir idioma objetivo
            target_language = input("¿A qué idioma deseas traducir? (EN, FR, DE, IT, PT): ").upper()
            if target_language in models:
                translation = translate_from_spanish(text, target_language, models)
                print(f"Traducción: {translation}")
                
                # Pedir la referencia y calcular BLEU
                reference = input("Por favor, introduce la traducción de referencia: ").split()
                print(f"Traducción de referencia: {' '.join(reference)}")  # Imprimir la referencia completa
                candidate = translation.split()
                bleu_score = calculate_bleu(reference, candidate)
                print(f"Puntaje BLEU: {bleu_score:.4f}")
            else:
                print("Lo siento, idioma no soportado.")
        elif detected_language in ['eng', 'fra', 'deu', 'por', 'ita']:
            # Traducción a español
            language_map = {'eng': 'ENR', 'fra': 'FRR', 'deu': 'DER', 'por': 'PTR', 'ita': 'ITR'}
            model = models.get(language_map[detected_language])
            if model:
                translation = translate_to_spanish(text, model)
                print(f"Traducción al español: {translation}")
                
                # Pedir la referencia y calcular BLEU
                reference = input("Por favor, introduce la traducción de referencia: ").split()
                print(f"Traducción de referencia: {' '.join(reference)}")  # Imprimir la referencia completa
                candidate = translation.split()
                bleu_score = calculate_bleu(reference, candidate)
                print(f"Puntaje BLEU: {bleu_score:.4f}")
            else:
                print(f"Lo siento, no tenemos soporte para traducir desde {detected_language}.")
        else:
            print(f"Idioma detectado no soportado: {detected_language}.")
    except Exception as e:
        print(f"Ocurrió un error: {e}")


if __name__ == "__main__":
    main()
# Out:
# Modelos de traducción cargados.
# Modelo de detección de idioma cargado.
# Predicción del modelo (índice): 0
# Idioma detectado: spa
# Traducción: i don ' t want to spend the rest of my life .
# Traducción de referencia: i don ' t want to spend the rest of my life regretting it .
# Puntaje BLEU: 0.7979
